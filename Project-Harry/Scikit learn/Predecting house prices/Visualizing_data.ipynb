# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
strat_train_set = pd.read_csv("strat_train_set.csv")
strat_test_set = pd.read_csv("strat_test_set.csv")

# %%
strat_train_set
# Out:
#        Unnamed: 0  longitude  latitude  housing_median_age  total_rooms  \
# 0           12655    -121.46     38.52                29.0       3873.0
# 1           15502    -117.23     33.09                 7.0       5320.0
# 2            2908    -119.04     35.37                44.0       1618.0
# 3           14053    -117.13     32.75                24.0       1877.0
# 4           20496    -118.70     34.28                27.0       3536.0
# ...           ...        ...       ...                 ...          ...
# 16507       15174    -117.07     33.03                14.0       6665.0
# 16508       12661    -121.42     38.51                15.0       7901.0
# 16509       19263    -122.72     38.44                48.0        707.0
# 16510       19140    -122.70     38.31                14.0       3155.0
# 16511       19773    -122.14     39.97                27.0       1079.0
#
#        total_bedrooms  population  households  median_income  \
# 0               797.0      2237.0       706.0         2.1736
# 1               855.0      2015.0       768.0         6.3373
# 2               310.0       667.0       300.0         2.8750
# 3               519.0       898.0       483.0         2.2264
# 4               646.0      1837.0       580.0         4.4964
# ...               ...         ...         ...            ...
# 16507          1231.0      2026.0      1001.0         5.0900
# 16508          1422.0      4769.0      1418.0         2.8139
# 16509           166.0       458.0       172.0         3.1797
# 16510           580.0      1208.0       501.0         4.1964
# 16511           222.0       625.0       197.0         3.1319
#
#        median_house_value ocean_proximity  income_cat
# 0                 72100.0          INLAND           2
# 1                279600.0      NEAR OCEAN           5
# 2                 82700.0          INLAND           2
# 3                112500.0      NEAR OCEAN           2
# 4                238300.0       <1H OCEAN           3
# ...                   ...             ...         ...
# 16507            268500.0       <1H OCEAN           4
# 16508             90400.0          INLAND           2
# 16509            140400.0       <1H OCEAN           3
# 16510            258100.0       <1H OCEAN           3
# 16511             62700.0          INLAND           3
#
# [16512 rows x 12 columns]

# %%
strat_train_set.drop("income_cat", axis=1, inplace=True)
strat_test_set.drop("income_cat", axis=1, inplace=True)

# %%
strat_train_set
# Out:
#        Unnamed: 0  longitude  latitude  housing_median_age  total_rooms  \
# 0           12655    -121.46     38.52                29.0       3873.0
# 1           15502    -117.23     33.09                 7.0       5320.0
# 2            2908    -119.04     35.37                44.0       1618.0
# 3           14053    -117.13     32.75                24.0       1877.0
# 4           20496    -118.70     34.28                27.0       3536.0
# ...           ...        ...       ...                 ...          ...
# 16507       15174    -117.07     33.03                14.0       6665.0
# 16508       12661    -121.42     38.51                15.0       7901.0
# 16509       19263    -122.72     38.44                48.0        707.0
# 16510       19140    -122.70     38.31                14.0       3155.0
# 16511       19773    -122.14     39.97                27.0       1079.0
#
#        total_bedrooms  population  households  median_income  \
# 0               797.0      2237.0       706.0         2.1736
# 1               855.0      2015.0       768.0         6.3373
# 2               310.0       667.0       300.0         2.8750
# 3               519.0       898.0       483.0         2.2264
# 4               646.0      1837.0       580.0         4.4964
# ...               ...         ...         ...            ...
# 16507          1231.0      2026.0      1001.0         5.0900
# 16508          1422.0      4769.0      1418.0         2.8139
# 16509           166.0       458.0       172.0         3.1797
# 16510           580.0      1208.0       501.0         4.1964
# 16511           222.0       625.0       197.0         3.1319
#
#        median_house_value ocean_proximity
# 0                 72100.0          INLAND
# 1                279600.0      NEAR OCEAN
# 2                 82700.0          INLAND
# 3                112500.0      NEAR OCEAN
# 4                238300.0       <1H OCEAN
# ...                   ...             ...
# 16507            268500.0       <1H OCEAN
# 16508             90400.0          INLAND
# 16509            140400.0       <1H OCEAN
# 16510            258100.0       <1H OCEAN
# 16511             62700.0          INLAND
#
# [16512 rows x 11 columns]

# %%
strat_train_set.to_csv("strat_train_set.csv")
strat_test_set.to_csv("strat_test_set.csv")

# %%
strat_train_set = pd.read_csv("strat_train_set.csv")
strat_test_set = pd.read_csv("strat_test_set.csv")

# %%
df = strat_train_set.copy()

# %%
df.plot(kind='scatter', x="latitude", y='longitude', grid='true',alpha=0.3)
# Out:
# <Axes: xlabel='latitude', ylabel='longitude'>

# %%
df.plot(kind='scatter', x="latitude", y='longitude', grid='true', cmap='jet', c="median_house_value")
# Out:
# <Axes: xlabel='latitude', ylabel='longitude'>
